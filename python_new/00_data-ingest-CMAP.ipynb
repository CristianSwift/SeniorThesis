# %% [markdown]
# # Loading Functions

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Creating Real Time data set
# ### Datetime is in UTC

# %%
realtime_path = '/Users/cristianswift/Desktop/Spring-Quarter-2022-2023/SeniorThesis/data/SeaFlow_realtime_TN413.csv'

#changing column naes so that the date is just called data
realtime_cols = ['time',
 'lat',
 'lon',
 'population',
 'abundance_cells_per_microliter',
 'diameter_micrometer']

#reading in the csv to a pandas df
realtime = pd.read_csv(realtime_path, names=realtime_cols)
# getting rid of the first row since it has the column names repeated
realtime = realtime.tail(-1)
realtime
# Out:
#                        time       lat        lon population  \
# 1      2023-02-25T05:45:57Z   21.3067  -157.0366    picoeuk
# 2      2023-02-25T05:51:57Z   21.3148  -157.0362  prochloro
# 3      2023-02-25T05:54:58Z   21.3142  -157.0321    picoeuk
# 4      2023-02-25T05:54:58Z   21.3142  -157.0321  prochloro
# 5      2023-02-25T05:57:58Z   21.3133  -157.0266  prochloro
# ...                     ...       ...        ...        ...
# 10570  2023-03-11T08:30:41Z  -19.4207  -181.8025    synecho
# 10571  2023-03-11T08:33:41Z  -19.4208   -181.792    picoeuk
# 10572  2023-03-11T08:36:41Z  -19.4207  -181.7817    picoeuk
# 10573  2023-03-11T08:36:41Z  -19.4207  -181.7817  prochloro
# 10574  2023-03-11T08:36:41Z  -19.4207  -181.7817    synecho
#
#       abundance_cells_per_microliter diameter_micrometer
# 1                  14.30323085044253    1.55786005995454
# 2                  59.90896889937337   0.663476451861207
# 3                  20.71698119210922  1.5760000524204352
# 4                  64.44967710586306   0.670356077823434
# 5                  68.45117621283211  0.6805887892801286
# ...                              ...                 ...
# 10570            0.25541483661504516    1.07457158316671
# 10571              4.370431648746329   1.985346246474965
# 10572              4.427190501327449    2.01327502068565
# 10573              92.26151487061243   0.572558873170014
# 10574             0.2837942629056057   0.959303192228264
#
# [10574 rows x 6 columns]

# %% [markdown]
# ## Averaging data over 10 minute resolution

# %%
realtime['abundance_cells_per_microliter'] = pd.to_numeric(realtime['abundance_cells_per_microliter'])

realtime = realtime.dropna(subset=['time','lat', 'lon']).reset_index().drop('index',axis=1)
realtime['time'] = realtime['time'].str[:-1]
realtime['lat'] = realtime['lat'].astype(float)
realtime['lon'] = realtime['lon'].astype(float)
realtime['abundance_cells_per_microliter'] = realtime['abundance_cells_per_microliter'].astype(float)
realtime['diameter_micrometer'] = realtime['diameter_micrometer'].astype(float)
realtime['depth'] = 0

print(realtime.dtypes)
realtime.head(4)
# Out:
# time                               object
# lat                               float64
# lon                               float64
# population                         object
# abundance_cells_per_microliter    float64
# diameter_micrometer               float64
# depth                               int64
# dtype: object
#                   time      lat       lon population  \
# 0  2023-02-25T05:45:57  21.3067 -157.0366    picoeuk
# 1  2023-02-25T05:51:57  21.3148 -157.0362  prochloro
# 2  2023-02-25T05:54:58  21.3142 -157.0321    picoeuk
# 3  2023-02-25T05:54:58  21.3142 -157.0321  prochloro
#
#    abundance_cells_per_microliter  diameter_micrometer  depth
# 0                       14.303231             1.557860      0
# 1                       59.908969             0.663476      0
# 2                       20.716981             1.576000      0
# 3                       64.449677             0.670356      0

# %%
#averaging over every 10 min
realtime['time'] = pd.to_datetime(realtime['time'])
#this drops the phytoplankton population categorical column, need to recalulate
realtime_avg = (realtime
                .groupby('population')
                .resample('10min', on='time')
                .mean(numeric_only=False)
                .reset_index()
               )
realtime_avg
# making time a string object again
realtime_avg['time'] = realtime_avg['time'].astype(str)
realtime_avg['time'] = realtime_avg['time'].str.replace(' ', 'T')
# Out:
# /var/folders/w6/gkpzzsjx0n101092kzm2dnh00000gn/T/ipykernel_94177/1411325747.py:7: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   .mean(numeric_only=False)
# /var/folders/w6/gkpzzsjx0n101092kzm2dnh00000gn/T/ipykernel_94177/1411325747.py:7: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   .mean(numeric_only=False)
# /var/folders/w6/gkpzzsjx0n101092kzm2dnh00000gn/T/ipykernel_94177/1411325747.py:7: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   .mean(numeric_only=False)

# %%
realtime_avg.dropna()
# Out:
#      population                 time       lat        lon  \
# 0       picoeuk  2023-02-25T05:40:00  21.30670 -157.03660
# 1       picoeuk  2023-02-25T05:50:00  21.31420 -157.03210
# 2       picoeuk  2023-02-25T06:00:00  21.31230 -157.01680
# 3       picoeuk  2023-02-25T06:10:00  21.31170 -156.99750
# 4       picoeuk  2023-02-25T06:20:00  21.31105 -156.98050
# ...         ...                  ...       ...        ...
# 5884    synecho  2023-03-11T07:30:00 -19.42570 -181.98925
# 5885    synecho  2023-03-11T07:40:00 -19.42510 -181.95800
# 5887    synecho  2023-03-11T08:00:00 -19.42280 -181.87520
# 5889    synecho  2023-03-11T08:20:00 -19.42080 -181.81290
# 5890    synecho  2023-03-11T08:30:00 -19.42070 -181.79210
#
#       abundance_cells_per_microliter  diameter_micrometer  depth
# 0                          14.303231             1.557860    0.0
# 1                          20.716981             1.576000    0.0
# 2                          22.590023             1.606258    0.0
# 3                          20.915637             1.544307    0.0
# 4                          22.320419             1.549379    0.0
# ...                              ...                  ...    ...
# 5884                        0.482450             1.016515    0.0
# 5885                        0.368933             1.136124    0.0
# 5887                        0.283794             1.008841    0.0
# 5889                        0.283794             1.296998    0.0
# 5890                        0.269605             1.016937    0.0
#
# [4493 rows x 7 columns]

# %% [markdown]
# # Using SimonCMAP to gather additional features

# %% [markdown]
# #### First installing and importing pycmap

# %%
# !pip install pycmap
import pycmap

# %% [markdown]
# ### Prepping realtime data for colocalization using Simon's CMAP

# %% [markdown]
# #### Setting API

# %%
api = pycmap.API(token='<6e1eb1d3-d364-4dfb-9121-8c23369dbbbe>')

# %%
api.get_dataset_metadata('tblPisces_Forecast_cl1')
# Out:
#    Variable              Table_Name  \
# 0       chl  tblPisces_Forecast_cl1
# 1    dissic  tblPisces_Forecast_cl1
# 2        fe  tblPisces_Forecast_cl1
# 3       no3  tblPisces_Forecast_cl1
# 4      nppv  tblPisces_Forecast_cl1
# 5        o2  tblPisces_Forecast_cl1
# 6        ph  tblPisces_Forecast_cl1
# 7      phyc  tblPisces_Forecast_cl1
# 8       po4  tblPisces_Forecast_cl1
# 9        si  tblPisces_Forecast_cl1
# 10    spco2  tblPisces_Forecast_cl1
# 11     talk  tblPisces_Forecast_cl1
#
#                                             Long_Name       Unit   Make  \
# 0    Mass Concentration of Chlorophyll a in Sea Water     mg/m^3  Model
# 1   Mole Concentration of Dissolved Inorganic Carb...    mol/m^3  Model
# 2   Mole Concentration of Dissolved Iron in Sea Water   mmol/m^3  Model
# 3          Mole Concentration of Nitrate in Sea Water   mmol/m^3  Model
# 4   Net Primary Production of Biomass Expressed as...  g/m^3/day  Model
# 5   Mole Concentration of Dissolved Oxygen in Sea ...   mmol/m^3  Model
# 6                Sea Water pH Reported on Total Scale        NaN  Model
# 7   Mole Concentration of Phytoplankton Expressed ...   mmol/m^3  Model
# 8        Mole Concentration of Phosphate in Sea Water   mmol/m^3  Model
# 9         Mole Concentration of Silicate in Sea Water   mmol/m^3  Model
# 10  Surface Partial Pressure of Carbon Dioxide in ...        NaN  Model
# 11  Sea Water Alkalinity Expressed as Mole Equivalent    mol/m^3  Model
#
#    Sensor Process_Level     Study_Domain Temporal_Resolution  \
# 0   Blend   Reprocessed  Biogeochemistry               Daily
# 1   Blend   Reprocessed  Biogeochemistry               Daily
# 2   Blend   Reprocessed  Biogeochemistry               Daily
# 3   Blend   Reprocessed  Biogeochemistry               Daily
# 4   Blend   Reprocessed  Biogeochemistry               Daily
# 5   Blend   Reprocessed  Biogeochemistry               Daily
# 6   Blend   Reprocessed  Biogeochemistry               Daily
# 7   Blend   Reprocessed  Biogeochemistry               Daily
# 8   Blend   Reprocessed  Biogeochemistry               Daily
# 9   Blend   Reprocessed  Biogeochemistry               Daily
# 10  Blend   Reprocessed  Biogeochemistry               Daily
# 11  Blend   Reprocessed  Biogeochemistry               Daily
#
#    Spatial_Resolution  ...                                 Dataset_Short_Name  \
# 0       1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
# 1       1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
# 2       1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
# 3       1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
# 4       1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
# 5       1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
# 6       1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
# 7       1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
# 8       1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
# 9       1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
# 10      1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
# 11      1/4Â° X 1/4Â°  ...  Mercator_Pisces_Biogeochemistry_Daily_Forecast...
#
#                                          Data_Source  \
# 0   CMEMS - Global Monitoring and Forecasting Centre
# 1   CMEMS - Global Monitoring and Forecasting Centre
# 2   CMEMS - Global Monitoring and Forecasting Centre
# 3   CMEMS - Global Monitoring and Forecasting Centre
# 4   CMEMS - Global Monitoring and Forecasting Centre
# 5   CMEMS - Global Monitoring and Forecasting Centre
# 6   CMEMS - Global Monitoring and Forecasting Centre
# 7   CMEMS - Global Monitoring and Forecasting Centre
# 8   CMEMS - Global Monitoring and Forecasting Centre
# 9   CMEMS - Global Monitoring and Forecasting Centre
# 10  CMEMS - Global Monitoring and Forecasting Centre
# 11  CMEMS - Global Monitoring and Forecasting Centre
#
#                     Distributor  \
# 0   http://marine.copernicus.eu
# 1   http://marine.copernicus.eu
# 2   http://marine.copernicus.eu
# 3   http://marine.copernicus.eu
# 4   http://marine.copernicus.eu
# 5   http://marine.copernicus.eu
# 6   http://marine.copernicus.eu
# 7   http://marine.copernicus.eu
# 8   http://marine.copernicus.eu
# 9   http://marine.copernicus.eu
# 10  http://marine.copernicus.eu
# 11  http://marine.copernicus.eu
#
#                                   Dataset_Description  \
# 0   "The Operational Mercator Ocean biogeochemical...
# 1   "The Operational Mercator Ocean biogeochemical...
# 2   "The Operational Mercator Ocean biogeochemical...
# 3   "The Operational Mercator Ocean biogeochemical...
# 4   "The Operational Mercator Ocean biogeochemical...
# 5   "The Operational Mercator Ocean biogeochemical...
# 6   "The Operational Mercator Ocean biogeochemical...
# 7   "The Operational Mercator Ocean biogeochemical...
# 8   "The Operational Mercator Ocean biogeochemical...
# 9   "The Operational Mercator Ocean biogeochemical...
# 10  "The Operational Mercator Ocean biogeochemical...
# 11  "The Operational Mercator Ocean biogeochemical...
#
#                                       Acknowledgement  Dataset_ID     ID  \
# 0   Data provided by: E.U. Copernicus Marine Servi...         523  10699
# 1   Data provided by: E.U. Copernicus Marine Servi...         523  10710
# 2   Data provided by: E.U. Copernicus Marine Servi...         523  10700
# 3   Data provided by: E.U. Copernicus Marine Servi...         523  10702
# 4   Data provided by: E.U. Copernicus Marine Servi...         523  10706
# 5   Data provided by: E.U. Copernicus Marine Servi...         523  10701
# 6   Data provided by: E.U. Copernicus Marine Servi...         523  10707
# 7   Data provided by: E.U. Copernicus Marine Servi...         523  10704
# 8   Data provided by: E.U. Copernicus Marine Servi...         523  10703
# 9   Data provided by: E.U. Copernicus Marine Servi...         523  10705
# 10  Data provided by: E.U. Copernicus Marine Servi...         523  10708
# 11  Data provided by: E.U. Copernicus Marine Servi...         523  10709
#
#     Visualize                                           Keywords  Refrences
# 0           1  0.25, 1/4 degree, 3D, biogeochemistry, blend, ...        NaN
# 1           1  0.25, 1/4 degree, 3D, biogeochemistry, blend, ...        NaN
# 2           1  0.25, 1/4 degree, 3D, biogeochemistry, blend, ...        NaN
# 3           1  0.25, 1/4 degree, 3D, biogeochemistry, blend, ...        NaN
# 4           1  0.25, 1/4 degree, 3D, biogeochemistry, blend, ...        NaN
# 5           1  0.25, 1/4 degree, 3D, biogeochemistry, blend, ...        NaN
# 6           1  0.25, 1/4 degree, 3D, biogeochemistry, blend, ...        NaN
# 7           1  0.25, 1/4 degree, 3D, biogeochemistry, blend, ...        NaN
# 8           1  0.25, 1/4 degree, 3D, biogeochemistry, blend, ...        NaN
# 9           1  0.25, 1/4 degree, 3D, biogeochemistry, blend, ...        NaN
# 10          1  0.25, 1/4 degree, 3D, biogeochemistry, blend, ...        NaN
# 11          1  0.25, 1/4 degree, 3D, alk, biogeochemistry, bl...        NaN
#
# [12 rows x 38 columns]

# %%
targets = {
        
        # BioGeoChemical Numerical Near-Real-Time Model
        "tblPisces_Forecast_cl1": {
                          "variables": ["NO3", "PO4", "Fe", "Si", "chl", "nppv"],
                          "tolerances": [4, 0.5, 0.5, 5]
                         }
        }


source = realtime_avg

realtime_cmap = pycmap.Sample(
              source=source, 
              targets=targets, 
              replaceWithMonthlyClimatolog=False
             )

# %%
realtime_cmap

# %%
realtime_cmap.to_csv('/Users/cristianswift/Desktop/Spring-Quarter-2022-2023/SeniorThesis/data/realtime_cmap.csv', index=False)

# %% [markdown]
# ## Doing the same to the covariate dataset

# %%
covari_path = '/Users/cristianswift/Desktop/Spring-Quarter-2022-2023/SeniorThesis/data/covari_cmap_ready.csv'
covari = pd.read_csv(covari_path, usecols=lambda column: column != 'Unnamed: 0')

covari = covari[['date', 'PopulationName', 'lat', 'lon', 'biomass', 'salin', 'temp', 'cruisename']]
# # making time a string object again
covari['date'] = covari['date'].astype(str)
covari['date'] = covari['date'].str.replace('Z', '')
covari = covari.rename(columns={'date': 'time'})
covari
# Out:
#                       time   PopulationName        lat         lon    biomass  \
# 0      2016-04-20T00:00:00  Prochlorococcus        NaN         NaN   9.232478
# 1      2016-04-20T00:00:00    Synechococcus        NaN         NaN   0.279172
# 2      2016-04-20T00:00:00      non_pro_syn        NaN         NaN   3.079118
# 3      2016-04-20T00:00:00      non_pro_syn        NaN         NaN   0.606572
# 4      2016-04-20T01:00:00  Prochlorococcus        NaN         NaN  10.175402
# ...                    ...              ...        ...         ...        ...
# 12182  2021-12-30T00:00:00      non_pro_syn  32.673493 -117.545342   3.774488
# 12183  2021-12-30T01:00:00  Prochlorococcus  32.682100 -117.660321   0.874599
# 12184  2021-12-30T01:00:00    Synechococcus  32.682100 -117.660321   9.707579
# 12185  2021-12-30T01:00:00      non_pro_syn  32.682100 -117.660321   2.428084
# 12186  2021-12-30T01:00:00      non_pro_syn  32.682100 -117.660321   3.785184
#
#            salin       temp cruisename
# 0      34.679128  25.740547    KOK1606
# 1      34.679128  25.740547    KOK1606
# 2      34.679128  25.740547    KOK1606
# 3      34.679128  25.740547    KOK1606
# 4      34.704286  25.624466    KOK1606
# ...          ...        ...        ...
# 12182  33.468151  15.189021      TN398
# 12183  33.478846  15.327302      TN398
# 12184  33.478846  15.327302      TN398
# 12185  33.478846  15.327302      TN398
# 12186  33.478846  15.327302      TN398
#
# [12187 rows x 8 columns]

# %%
targets = {
        
        # BioGeoChemical Numerical Near-Real-Time Model
        "tblPisces_NRT": {
                          "variables": ["NO3", "PO4", "Fe", "Si", "chl"],
                          "tolerances": [4, 0.5, 0.5, 5]
                         },
    
    "tblPisces_Forecast": {
                          "variables": ["NO3", "PO4", "Fe", "Si", "chl"],
                          "tolerances": [4, 0.5, 0.5, 5]
        }
}

source = covari
covari_cmap = pycmap.Sample(
              source=source, 
              targets=targets, 
              replaceWithMonthlyClimatolog=False
             )
# Out:
# Gathering metadata ....
# Sampling starts
# Sampling finished

# %%
covari_cmap

# %%
covari_cmap
# Out:
#                       time   PopulationName        lat         lon    biomass  \
# 0      2016-04-20T00:00:00  Prochlorococcus        NaN         NaN   9.232478
# 1      2016-04-20T00:00:00    Synechococcus        NaN         NaN   0.279172
# 2      2016-04-20T00:00:00      non_pro_syn        NaN         NaN   3.079118
# 3      2016-04-20T00:00:00      non_pro_syn        NaN         NaN   0.606572
# 4      2016-04-20T01:00:00  Prochlorococcus        NaN         NaN  10.175402
# ...                    ...              ...        ...         ...        ...
# 12182  2021-12-30T00:00:00      non_pro_syn  32.673493 -117.545342   3.774488
# 12183  2021-12-30T01:00:00  Prochlorococcus  32.682100 -117.660321   0.874599
# 12184  2021-12-30T01:00:00    Synechococcus  32.682100 -117.660321   9.707579
# 12185  2021-12-30T01:00:00      non_pro_syn  32.682100 -117.660321   2.428084
# 12186  2021-12-30T01:00:00      non_pro_syn  32.682100 -117.660321   3.785184
#
#            salin       temp cruisename  CMAP_NO3_tblPisces_NRT  \
# 0      34.679128  25.740547    KOK1606                     NaN
# 1      34.679128  25.740547    KOK1606                     NaN
# 2      34.679128  25.740547    KOK1606                     NaN
# 3      34.679128  25.740547    KOK1606                     NaN
# 4      34.704286  25.624466    KOK1606                     NaN
# ...          ...        ...        ...                     ...
# 12182  33.468151  15.189021      TN398                     NaN
# 12183  33.478846  15.327302      TN398                     NaN
# 12184  33.478846  15.327302      TN398                     NaN
# 12185  33.478846  15.327302      TN398                     NaN
# 12186  33.478846  15.327302      TN398                     NaN
#
#        CMAP_PO4_tblPisces_NRT  CMAP_Fe_tblPisces_NRT  CMAP_Si_tblPisces_NRT  \
# 0                         NaN                    NaN                    NaN
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 12182                     NaN                    NaN                    NaN
# 12183                     NaN                    NaN                    NaN
# 12184                     NaN                    NaN                    NaN
# 12185                     NaN                    NaN                    NaN
# 12186                     NaN                    NaN                    NaN
#
#        CMAP_chl_tblPisces_NRT
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 12182                     NaN
# 12183                     NaN
# 12184                     NaN
# 12185                     NaN
# 12186                     NaN
#
# [12187 rows x 13 columns]

# %%
covari_cmap.to_csv('/Users/cristianswift/Desktop/Spring-Quarter-2022-2023/SeniorThesis/data/covari_cmap.csv', index=False)

# %%
#changing column naes so that the date is just called data
covari_cols = ['time',
 'lat',
 'lon',
 'population',
 'abundance_cells_per_microliter',
 'diameter_micrometer']

#reading in the csv to a pandas df
realtime = pd.read_csv(realtime_path, names=realtime_cols)
# getting rid of the first row since it has the column names repeated
realtime = realtime.tail(-1)
realtime
