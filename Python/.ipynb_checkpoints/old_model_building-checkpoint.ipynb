# %%
# %run 03_data-QAQC.ipynb
# Out:
#                        date          PopulationName          lat  \
# 1      2016-04-20T00:00:00Z         Prochlorococcus          NaN
# 2      2016-04-20T00:00:00Z           Synechococcus          NaN
# 3      2016-04-20T00:00:00Z  nanoeukaryotes (2-5µm)          NaN
# 4      2016-04-20T00:00:00Z  picoeukaryotes (< 2µm)          NaN
# 5      2016-04-20T01:00:00Z         Prochlorococcus          NaN
# ...                     ...                     ...          ...
# 12183  2021-12-30T00:00:00Z  picoeukaryotes (< 2µm)  32.67349333
# 12184  2021-12-30T01:00:00Z         Prochlorococcus  32.68209958
# 12185  2021-12-30T01:00:00Z           Synechococcus  32.68209958
# 12186  2021-12-30T01:00:00Z  nanoeukaryotes (2-5µm)  32.68209958
# 12187  2021-12-30T01:00:00Z  picoeukaryotes (< 2µm)  32.68209958
#
#                 lon cell_abundance      biomass   cellquotas cell_diameter  \
# 1               NaN     253.186148  9.232478116  0.036465179       0.57858
# 2               NaN    1.588988684  0.279172358  0.175691848       1.06425
# 3               NaN    1.332641539  3.079117581  2.310536998       2.88901
# 4               NaN    1.252646685    0.6065723  0.484232551       1.57653
# 5               NaN    262.0994355  10.17540209  0.038822678        0.5928
# ...             ...            ...          ...          ...           ...
# 12183  -117.5453421    11.39336675  3.774487646  0.331288172       1.36085
# 12184  -117.6603213     8.58666656  0.874598646  0.101855434       0.86154
# 12185  -117.6603213    31.43752583  9.707578705  0.308789526       1.32425
# 12186  -117.6603213    1.794657118  2.428083968   1.35295146       2.34779
# 12187  -117.6603213    9.747117403    3.7851842  0.388338833       1.44729
#
#              salin         temp cruisename Light_micromolQuanta_m2_s SiO4  \
# 1      34.67912841  25.74054659    KOK1606               1764.076136  NaN
# 2      34.67912841  25.74054659    KOK1606               1764.076136  NaN
# 3      34.67912841  25.74054659    KOK1606               1764.076136  NaN
# 4      34.67912841  25.74054659    KOK1606               1764.076136  NaN
# 5      34.70428621  25.62446552    KOK1606                1450.07931  NaN
# ...            ...          ...        ...                       ...  ...
# 12183  33.46815051   15.1890208      TN398                 127.69215  NaN
# 12184  33.47884556  15.32730222      TN398                    1.0128  NaN
# 12185  33.47884556  15.32730222      TN398                    1.0128  NaN
# 12186  33.47884556  15.32730222      TN398                    1.0128  NaN
# 12187  33.47884556  15.32730222      TN398                    1.0128  NaN
#
#       NO3NO2  PO4   Fe Satellite_CHL mixed_layer_depth
# 1        NaN  NaN  NaN           NaN       26.96643939
# 2        NaN  NaN  NaN           NaN       26.96643939
# 3        NaN  NaN  NaN           NaN       26.96643939
# 4        NaN  NaN  NaN           NaN       26.96643939
# 5        NaN  NaN  NaN           NaN       26.96643939
# ...      ...  ...  ...           ...               ...
# 12183    NaN  NaN  NaN           NaN               NaN
# 12184    NaN  NaN  NaN           NaN               NaN
# 12185    NaN  NaN  NaN           NaN               NaN
# 12186    NaN  NaN  NaN           NaN               NaN
# 12187    NaN  NaN  NaN           NaN               NaN
#
# [12187 rows x 18 columns]
#
#
# date                         object
# PopulationName               object
# lat                          object
# lon                          object
# cell_abundance               object
# biomass                      object
# cellquotas                   object
# cell_diameter                object
# salin                        object
# temp                         object
# cruisename                   object
# Light_micromolQuanta_m2_s    object
# SiO4                         object
# NO3NO2                       object
# PO4                          object
# Fe                           object
# Satellite_CHL                object
# mixed_layer_depth            object
# dtype: object
#
#
#                            date          PopulationName        lat  \
# 1     2016-04-20 00:00:00+00:00         Prochlorococcus        NaN
# 2     2016-04-20 00:00:00+00:00           Synechococcus        NaN
# 3     2016-04-20 00:00:00+00:00  nanoeukaryotes (2-5µm)        NaN
# 4     2016-04-20 00:00:00+00:00  picoeukaryotes (< 2µm)        NaN
# 5     2016-04-20 01:00:00+00:00         Prochlorococcus        NaN
# ...                         ...                     ...        ...
# 12183 2021-12-30 00:00:00+00:00  picoeukaryotes (< 2µm)  32.673493
# 12184 2021-12-30 01:00:00+00:00         Prochlorococcus  32.682100
# 12185 2021-12-30 01:00:00+00:00           Synechococcus  32.682100
# 12186 2021-12-30 01:00:00+00:00  nanoeukaryotes (2-5µm)  32.682100
# 12187 2021-12-30 01:00:00+00:00  picoeukaryotes (< 2µm)  32.682100
#
#               lon  cell_abundance    biomass  cellquotas  cell_diameter  \
# 1             NaN      253.186148   9.232478    0.036465        0.57858
# 2             NaN        1.588989   0.279172    0.175692        1.06425
# 3             NaN        1.332642   3.079118    2.310537        2.88901
# 4             NaN        1.252647   0.606572    0.484233        1.57653
# 5             NaN      262.099436  10.175402    0.038823        0.59280
# ...           ...             ...        ...         ...            ...
# 12183 -117.545342       11.393367   3.774488    0.331288        1.36085
# 12184 -117.660321        8.586667   0.874599    0.101855        0.86154
# 12185 -117.660321       31.437526   9.707579    0.308790        1.32425
# 12186 -117.660321        1.794657   2.428084    1.352951        2.34779
# 12187 -117.660321        9.747117   3.785184    0.388339        1.44729
#
#            salin       temp cruisename  Light_micromolQuanta_m2_s  SiO4  \
# 1      34.679128  25.740547    KOK1606                1764.076136   NaN
# 2      34.679128  25.740547    KOK1606                1764.076136   NaN
# 3      34.679128  25.740547    KOK1606                1764.076136   NaN
# 4      34.679128  25.740547    KOK1606                1764.076136   NaN
# 5      34.704286  25.624466    KOK1606                1450.079310   NaN
# ...          ...        ...        ...                        ...   ...
# 12183  33.468151  15.189021      TN398                 127.692150   NaN
# 12184  33.478846  15.327302      TN398                   1.012800   NaN
# 12185  33.478846  15.327302      TN398                   1.012800   NaN
# 12186  33.478846  15.327302      TN398                   1.012800   NaN
# 12187  33.478846  15.327302      TN398                   1.012800   NaN
#
#        NO3NO2  PO4  Fe  Satellite_CHL  mixed_layer_depth
# 1         NaN  NaN NaN            NaN          26.966439
# 2         NaN  NaN NaN            NaN          26.966439
# 3         NaN  NaN NaN            NaN          26.966439
# 4         NaN  NaN NaN            NaN          26.966439
# 5         NaN  NaN NaN            NaN          26.966439
# ...       ...  ...  ..            ...                ...
# 12183     NaN  NaN NaN            NaN                NaN
# 12184     NaN  NaN NaN            NaN                NaN
# 12185     NaN  NaN NaN            NaN                NaN
# 12186     NaN  NaN NaN            NaN                NaN
# 12187     NaN  NaN NaN            NaN                NaN
#
# [12187 rows x 18 columns]
#
#
# date                         datetime64[ns, UTC]
# PopulationName                            object
# lat                                      float64
# lon                                      float64
# cell_abundance                           float64
# biomass                                  float64
# cellquotas                               float64
# cell_diameter                            float64
# salin                                    float64
# temp                                     float64
# cruisename                                object
# Light_micromolQuanta_m2_s                float64
# SiO4                                     float64
# NO3NO2                                   float64
# PO4                                      float64
# Fe                                       float64
# Satellite_CHL                            float64
# mixed_layer_depth                        float64
# dtype: object
# /var/folders/w6/gkpzzsjx0n101092kzm2dnh00000gn/T/ipykernel_61249/617929011.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /var/folders/w6/gkpzzsjx0n101092kzm2dnh00000gn/T/ipykernel_61249/1463451283.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covari['PopulationName'] = covari['PopulationName'].replace(
# No NaNs found, Yay!
# biomass  PO4              0.503028
# PO4      biomass          0.503028
# NO3NO2   biomass          0.504095
# biomass  NO3NO2           0.504095
# Fe       lat              0.520947
#                             ...
# salin    Satellite_CHL    0.977863
# temp     PO4              0.982861
# PO4      temp             0.982861
# temp     NO3NO2           0.984894
# NO3NO2   temp             0.984894
# Length: 64, dtype: float64

# %% [markdown]
# # Developing a Random Forest Regressor for Each Population to Predict Biomass (pgC per L)

# %% [markdown]
# ## Functions:

# %%
#function to make numpy array
def to_np(pop_feat):
    pop_feat = np.array(pop_feat)
    return pop_feat

# %% [markdown]
# ## Seperating dataframes for individual populations

# %%
covari.head(3)
# Out:
#                           date   PopulationName        lat        lon  \
# 2849 2017-08-05 02:00:00+00:00  Prochlorococcus  21.869125 -158.11889
# 2850 2017-08-05 02:00:00+00:00    Synechococcus  21.869125 -158.11889
# 2851 2017-08-05 02:00:00+00:00      non_pro_syn  21.869125 -158.11889
#
#       cell_abundance   biomass  cellquotas  cell_diameter      salin  \
# 2849      211.519050  8.967613    0.042396        0.61338  35.029785
# 2850        3.172882  2.320473    0.731346        1.84974  35.029785
# 2851        1.978374  7.015652    3.546171        3.41083  35.029785
#
#           temp cruisename  Light_micromolQuanta_m2_s       SiO4    NO3NO2  \
# 2849  27.79885     KM1712                 473.451935  11.331458  0.000002
# 2850  27.79885     KM1712                 473.451935  11.331458  0.000002
# 2851  27.79885     KM1712                 473.451935  11.331458  0.000002
#
#            PO4        Fe  Satellite_CHL  mixed_layer_depth
# 2849  0.328541  0.000067       0.039618          40.304435
# 2850  0.328541  0.000067       0.039618          40.304435
# 2851  0.328541  0.000067       0.039618          40.304435

# %%
pro_covari = covari[covari.PopulationName == 'Prochlorococcus']
syn_covari = covari[covari.PopulationName == 'Synechococcus']
non_covari = covari[covari.PopulationName == 'non_pro_syn']


pop_covari_list = [pro_covari, syn_covari, non_covari]
# creating the labels for all of the populations for biomass (using numpy array so we can predict on them)

label_pro = np.array(pro_covari.biomass)
label_syn = np.array(syn_covari.biomass)
label_non = np.array(non_covari.biomass)

# Creating the features for all of the populations

#these are the dropped features
droped_features = ['date','PopulationName','cell_abundance',
                   'biomass', 'cell_abundance',
                  'cell_diameter', 'cruisename', 'Light_micromolQuanta_m2_s',
                   'cellquotas', 'mixed_layer_depth']

features_pro = pro_covari.drop(droped_features, axis = 1)
features_syn = syn_covari.drop(droped_features, axis = 1)
features_non = non_covari.drop(droped_features, axis = 1)


# Saving feature names for later use (doesn't matter which dataframe we use since they all have same column names)
feature_list = list(features_pro.columns)
# Convert to numpy array
pop_features = [features_pro,features_syn,features_non]


features_pro = to_np(features_pro)
features_syn = to_np(features_syn)
features_non = to_np(features_non)

# %%
#loading packages for random forest modeling

from sklearn.model_selection import train_test_split
import joblib

# %% [markdown]
# ## RF Regressor for Prochlorococcus

# %%
# Using Skicit-learn to split data into training and testing sets
# Split the data into training and testing sets"
train_features, test_features, train_labels, test_labels = train_test_split(features_pro, label_pro, test_size = 0.25, random_state = 42)

# %%
# Looking at the shape of the features and labels to see if they match up
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (44, 9)
# Training Labels Shape: (44,)
# Testing Features Shape: (15, 9)
# Testing Labels Shape: (15,)

# %%
# We are using a regressor RF model because we are predicting on continous values
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 100 decision trees
rf_pro= RandomForestRegressor(n_estimators = 10, random_state = 42)
# Use the Training data to build the model
rf_pro.fit(train_features, train_labels)
#saving the model
joblib.dump(rf_pro, "/Users/cristianswift/Desktop/Spring-Quarter-2022-2023/SeniorThesis/RF_models/random_forest_pro.joblib")
# Out:
# ['/Users/cristianswift/Desktop/Spring-Quarter-2022-2023/SeniorThesis/RF_models/random_forest_pro.joblib']

# %% [markdown]
# ### Predicting and Testing for Prochlorococus

# %%
# Use the forest's predict method on the test data
predictions = rf_pro.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(test_labels, predictions)
print('Mean Absolute Error:', round(mae, 2), 'pgC per L.')
# Out:
# Mean Absolute Error: 0.47 pgC per L.

# %%
# Get numerical feature importances
importances = list(rf_pro.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# %%
pro_feature_importance = pd.DataFrame(rf_pro.feature_importances_, index=feature_list).sort_values(by=0, ascending=False)

# Import matplotlib for plotting and use magic command for Jupyter Notebooks
import matplotlib.pyplot as plt
# %matplotlib inline
# Set the style
plt.style.use('fivethirtyeight')
# Make a bar chart
plt.bar(x=pro_feature_importance.index,height=pro_feature_importance[0], orientation = 'vertical')
# Tick labels for x axis
plt.xticks(pro_feature_importance.index, feature_list, rotation=45, ha='right', rotation_mode='anchor')

# Axis labels and title
plt.ylabel('Importance'); plt.title('Variable Importances for Pro RF');

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 93.28 %.

# %%
cruise_tract(pro_covari)

# %%
fig, ax = plt.subplots()
ax.scatter(test_labels, predictions)
ax.set_title('PRO Model Predictions vs True Values')
ax.set_ylim(ymin=0)
ax.set_xlim(xmin=0)


# run the model on each individual populaton - see which does best
#put zero values when
# Out:
# (0.0, 9.70520555395)

# %% [markdown]
# ## RF Regressor for Synechococcus

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets"
train_features, test_features, train_labels, test_labels = train_test_split(features_syn, label_syn, test_size = 0.25, random_state = 42)

# %%
# Looking at the shape of the features and labels to see if they match up
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (105, 9)
# Training Labels Shape: (105,)
# Testing Features Shape: (35, 9)
# Testing Labels Shape: (35,)

# %%
# We are using a regressor RF model because we are predicting on continous values
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 100 decision trees
rf_syn = RandomForestRegressor(n_estimators = 10, random_state = 42)
# Use the Training data to build the model
rf_syn.fit(train_features, train_labels);
#saving the model
joblib.dump(rf_syn, "/Users/cristianswift/Desktop/Spring-Quarter-2022-2023/SeniorThesis/RF_models/random_forest_syn.joblib")
# Out:
# ['/Users/cristianswift/Desktop/Spring-Quarter-2022-2023/SeniorThesis/RF_models/random_forest_syn.joblib']

# %%
# Use the forest's predict method on the test data
predictions = rf_syn.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(test_labels, predictions)
print('Mean Absolute Error:', round(mae, 2), 'pgC per L.')
# Out:
# Mean Absolute Error: 0.14 pgC per L.

# %%
# Get numerical feature importances
importances = list(rf_syn.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# %%
pro_feature_importance = pd.DataFrame(rf_syn.feature_importances_, index=feature_list).sort_values(by=0, ascending=False)

# Import matplotlib for plotting and use magic command for Jupyter Notebooks
import matplotlib.pyplot as plt
# %matplotlib inline
# Set the style
plt.style.use('fivethirtyeight')
# Make a bar chart
plt.bar(x=pro_feature_importance.index,height=pro_feature_importance[0], orientation = 'vertical')
# Tick labels for x axis
plt.xticks(pro_feature_importance.index, feature_list, rotation=45, ha='right', rotation_mode='anchor')

# Axis labels and title
plt.ylabel('Importance'); plt.title('Variable Importances for SYN RF');

# %%
cruise_tract(syn_covari)

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 92.33 %.

# %%
fig, ax = plt.subplots()
ax.scatter(test_labels, predictions)
ax.set_title('SYN Model Predictions vs True Values')
ax.set_ylim(ymin=0)
ax.set_xlim(xmin=0)


# run the model on each individual populaton - see which does best
#put zero values when
# Out:
# (0.0, 3.9172343378)

# %% [markdown]
# ## RF Regressor for Non Pro or Syn

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets"
train_features, test_features, train_labels, test_labels = train_test_split(features_non, label_non, test_size = 0.25, random_state = 42)

# %%
# Looking at the shape of the features and labels to see if they match up
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (210, 9)
# Training Labels Shape: (210,)
# Testing Features Shape: (70, 9)
# Testing Labels Shape: (70,)

# %%
# We are using a regressor RF model because we are predicting on continous values
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 100 decision trees
rf_non = RandomForestRegressor(n_estimators = 10, random_state = 42)
# Use the Training data to build the model
rf_non.fit(train_features, train_labels);
joblib.dump(rf_non, "/Users/cristianswift/Desktop/Spring-Quarter-2022-2023/SeniorThesis/RF_models/random_forest_non_pro_syn.joblib")
# Out:
# ['/Users/cristianswift/Desktop/Spring-Quarter-2022-2023/SeniorThesis/RF_models/random_forest_non_pro_syn.joblib']

# %%
# Use the forest's predict method on the test data
predictions = rf_non.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(test_labels, predictions)
print('Mean Absolute Error:', round(mae, 2), 'pgC per L.')
# Out:
# Mean Absolute Error: 3.15 pgC per L.

# %%
# Get numerical feature importances
importances = list(rf_non.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# %%
non_feature_importance = pd.DataFrame(rf_non.feature_importances_, index=feature_list).sort_values(by=0, ascending=False)

# Import matplotlib for plotting and use magic command for Jupyter Notebooks
import matplotlib.pyplot as plt
# %matplotlib inline
# Set the style
plt.style.use('fivethirtyeight')
# Make a bar chart
plt.bar(x=non_feature_importance.index,height=non_feature_importance[0], orientation = 'vertical')
# Tick labels for x axis
plt.xticks(non_feature_importance.index, feature_list, rotation=45, ha='right', rotation_mode='anchor')

# Axis labels and title
plt.ylabel('Importance'); plt.title('Variable Importances for Non Syn or Pro RF');

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 4.57 %.

# %%
fig, ax = plt.subplots()
ax.scatter(test_labels, predictions)
ax.set_title('Non Syn or Pro Model Predictions vs True Values')
ax.set_ylim(ymin=0)
ax.set_xlim(xmin=0)


# run the model on each individual populaton - see which does best
#put zero values when
# Out:
# (0.0, 18.419319583700002)

# %%
cruise_tract(non_covari)
